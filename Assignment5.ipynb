# %%
#Guess a number is a game that prompts a player to guess a number between 0 and 9, which
#is randomly generated by the system. When the input given by the user matches the
#number generated by the system then the user wins. The game should go as follows:

#Guess the number: 5
#Sorry, try again
#Guess the number: 3
#Sorry, try again
#Guess the number: 8
#You got it right! Congo!

import random
random_num=random.randint(0,9)
i=0
while i<10:
        user=eval(input("Guess a number"))
        
        if random_num==user:
            print("You got it right! Congo!")
            break
        else:
            print("Sorry, try again")
# Out:
# Guess a number3
# You got it right! Congo!

# %%
#Make an improvement to the Guess a number game. Guide the user where they are
#standing and limit the number of attempts to 3. For example, the game should go like this:

#Guess the number: 4
#Too low
#Guess the number: 9
#Too high
#Guess the number: 5
#Sorry you Lost!

import random
random_num=random.randint(0,9)
i=0

while i<3:
    user=eval(input("Guess a Number :"))
    if random_num<user:
        print('Too Low')
    elif random_num>user:
        print('Too High')
    i=i+1

print('Sorry you Lost!')
# Out:
# Guess a Number :9
# Too Low
# Guess a Number :3
# Too Low
# Guess a Number :6
# Too Low
# Sorry you Lost!

# %%
#Let us make the above game a little more interesting by converting it into a gambling
#problem. Suppose that a player starts with Rs. 1,000. If a player can guess the number in his
#first chance, then he will be given a prize of Rs. 5,000, if he requires 2 attempts then he will
#get a prize of Rs.1,000. If he loses then he will lose Rs. 500. For example the game should go
#like this:

#You have a cash of Rs. 1,000 with you...
#Guess the number: 8
#Too high
#Guess the number: 3
#You have just won Rs. 1,000
#Your balance: Rs. 2000

import random
random_num=random.randint(0,9)
prize=1000

i=0
count=0
while i<3:
    user=eval(input("Guess a number:"))
    count=count+1
    if random_num==user:
        
        if count==1:
            print("You have won Rs.5000")
            prize=prize+5000
        elif count==2:
            print("You have won Rs.1000")
            prize=prize+1000
        else:
            print("You lost Rs.500")
            prize=prize-500
        break
        
    elif user<random_num:
        print('Too Low')
    elif user>random_num:
        print('Too High')
            
        i=i+1
        
print('Your balance is {}'.format(prize))
# Out:
# Guess a number:3
# Too Low
# Guess a number:9
# Too High
# Guess a number:4
# You lost Rs.500
# Your balance is 500

# %%
#Suppose that a player wants to play a game which requires him Rs. 1,000 to start. If the
#current balance in his account is less than Rs. 1,000 he needs to withdraw the extra money
#from his e-wallet.

#Note that if the sum of money in his courrent account and the amount withdrawn is greater than
#or equal to Rs. 1,000 then he can start playing the game. However if the sum is less than Rs.
#1,000 then the program should keep displaying the user the message “You still do not have
#enough money to start playing.” and keep prompting the user to withdraw money unless it
#crosses Rs. 1,000. Once ready, i.e. if his current account balance crosses Rs. 1,000, it will display
#a message “Now, you are ready to play the game.” Your program should also display the account
#balance and the current amount in the e-wallet.

import random
current_bal=int(input("entert the current balance"))
while current_bal<1000:
    print("You still do not have enough money to start playing ,with draw the amount from e-wallet")
    withdraw=int(input("enter the amount"))
    current_bal=current_bal+withdraw
if current_bal>=1000:
    print("Now, you are ready to play the game.")
    print(current_bal)
    x=random.randint(0,9)
    print(x)
    count123=3
    i=1
    print("you Have a cash of Rs.1,000 with you....")
    while i<=3:
        y=eval(input("Enter the number of your choice "))
        if x==y:
            print("you got it right! congo!",i)
            count123=count123-1
            print("no of chances",count123)
            break
        else:
            print("Sorry,try again")
            count123=count123-1
            print("no of chances left",count123)
        i=i+1
if count123==2:
    current_bal=current_bal+5000
    print("you won a cash prize of 5000---",current_bal)
elif count123==1:
    current_bal=current_bal+1000
    print("you won a cash prize of 1000---",current_bal)
else:
    current_bal=current_bal-500
    print("you lost 500----",current_bal)
# Out:
# entert the current balance900
# You still do not have enough money to start playing ,with draw the amount from e-wallet
# enter the amount700
# Now, you are ready to play the game.
# 1600
# 8
# you Have a cash of Rs.1,000 with you....
# Enter the number of your choice 5
# Sorry,try again
# no of chances left 2
# Enter the number of your choice 9
# Sorry,try again
# no of chances left 1
# Enter the number of your choice 8
# you got it right! congo! 3
# no of chances 0
# you lost 500---- 1100
